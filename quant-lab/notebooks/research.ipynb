# %% [markdown]
# # Quant Research Lab
# Persistent workspace for ML trading research. Codex adds cells here.

# %%
# Setup - run first
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import joblib
from pathlib import Path
from datetime import datetime
from tqdm import tqdm

from backtest.runner import run_backtest, load_market_data
from backtest.features import add_all_features, get_feature_list
from backtest.models import get_model, train_model, predict_signals, get_feature_importance

DATA_DIR = Path('../../data')
MODELS_DIR = Path('../models')
MODELS_DIR.mkdir(exist_ok=True)

# %matplotlib inline
print(f'Ready. Time: {datetime.now()}')

# %% [markdown]
# ---
# ## Experiments
# Add new experiments below.
